# %%
# !pip install pandas-datareader
# !pip install yfinance

# %%
# !pip install yahoofinancials
# Out:
# ...
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.14-py3-none-any.whl size=28712 sha256=b8a3f03bd81c6bbba1d1849839815ce87f19f22b335fd314ad9ca038a4e133a5
#   Stored in directory: c:\users\v-anudeept\appdata\local\pip\cache\wheels\df\33\51\592213372072da189a4ff8f471838cadcc91add5821f7b9b38
# Successfully built yahoofinancials
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

from datetime import datetime

# %%
from yahoofinancials import YahooFinancials


yahoo_financials = YahooFinancials('MSFT')
data = yahoo_financials.get_historical_price_data(start_date='2000-01-01', 
                                                   end_date='2022-12-31', 
                                                   time_interval='weekly')
 
msft_df = pd.DataFrame(data['MSFT']['prices'])
 
msft_df = msft_df.drop('date', axis=1).set_index('formatted_date')
msft_df.head(100)
# msft_df.set_index('date')
# Out:
#                      high        low       open      close     volume  \
# formatted_date
# 2000-01-01      59.312500  53.656250  58.687500  55.718750  288397200
# 2000-01-08      57.125000  50.750000  56.718750  56.125000  314800000
# 2000-01-15      58.250000  51.625000  55.906250  51.875000  303817800
# 2000-01-22      52.843750  48.625000  51.898438  49.125000  294666000
# 2000-01-29      54.000000  47.437500  48.812500  53.281250  297857800
# ...                   ...        ...        ...        ...        ...
# 2001-10-27      31.510000  29.049999  31.049999  30.700001  370256200
# 2001-11-03      33.029999  30.875000  30.930000  32.605000  316154000
# 2001-11-10      34.169998  31.825001  32.349998  32.875000  343709000
# 2001-11-17      33.900002  31.740000  33.125000  32.355000  188466600
# 2001-11-24      32.855000  31.365000  32.494999  32.105000  289607800
#
#                  adjclose
# formatted_date
# 2000-01-01      34.762814
# 2000-01-08      35.016281
# ...

# %%
msft_df.head(100)
# Out:
#                      high        low       open      close     volume  \
# formatted_date
# 2000-01-01      59.312500  53.656250  58.687500  55.718750  288397200
# 2000-01-08      57.125000  50.750000  56.718750  56.125000  314800000
# 2000-01-15      58.250000  51.625000  55.906250  51.875000  303817800
# 2000-01-22      52.843750  48.625000  51.898438  49.125000  294666000
# 2000-01-29      54.000000  47.437500  48.812500  53.281250  297857800
# ...                   ...        ...        ...        ...        ...
# 2001-10-27      31.510000  29.049999  31.049999  30.700001  370256200
# 2001-11-03      33.029999  30.875000  30.930000  32.605000  316154000
# 2001-11-10      34.169998  31.825001  32.349998  32.875000  343709000
# 2001-11-17      33.900002  31.740000  33.125000  32.355000  188466600
# 2001-11-24      32.855000  31.365000  32.494999  32.105000  289607800
#
#                  adjclose
# formatted_date
# 2000-01-01      34.762814
# 2000-01-08      35.016281
# ...

# %%
msft_df.tail()
# Out:
#                       high         low        open       close     volume  \
# formatted_date
# 2019-11-30      151.869995  146.649994  151.809998  151.750000  103331700
# 2019-12-07      154.889999  150.330002  151.070007  154.529999  100477600
# 2019-12-14      158.490005  153.750000  155.110001  157.410004  152135400
# 2019-12-21      159.550003  157.119995  158.119995  158.960007   59640800
# 2019-12-28      159.020004  156.729996  158.990005  157.589996   16348400
#
#                   adjclose
# formatted_date
# 2019-11-30      147.160095
# 2019-12-07      149.856033
# 2019-12-14      152.648911
# 2019-12-21      154.152023
# 2019-12-28      152.823410

# %%
msft_df = msft_df.query("formatted_date	 >= '2010-01-01' and formatted_date	 < '2019-11-11'")

# %%
msft_df.tail(120)
# Out:
#                      high        low       open      close     volume  \
# formatted_date
# 2010-01-02      31.100000  30.190001  30.620001  30.660000  248098200
# 2010-01-09      31.240000  29.910000  30.709999  30.860001  329671600
# 2010-01-16      31.240000  28.840000  30.750000  28.959999  276516500
# 2010-01-23      29.920000  27.660000  29.240000  28.180000  505364600
# 2010-01-30      28.790001  27.570000  28.389999  28.020000  360552800
# 2010-02-06      28.400000  27.570000  28.010000  27.930000  307718600
# 2010-02-13      29.030001  28.020000  28.129999  28.770000  185126800
# 2010-02-20      28.940001  28.020000  28.840000  28.670000  221245100
# 2010-02-27      29.299999  28.240000  28.770000  28.590000  284263800
# 2010-03-06      29.379999  28.500000  28.520000  29.270000  201627400
# 2010-03-13      29.900000  29.010000  29.180000  29.590000  249798500
# 2010-03-20      30.570000  29.389999  29.500000  29.660000  242496700
# ...

# %%
msft_df['high'].max()
# Out:
# 31.579999923706055

# %%
msft_df.loc[msft_df['high']==31.579999923706055]
# Out:
#                  high    low   open      close     volume   adjclose
# formatted_date
# 2010-04-17      31.58  30.65  30.77  30.959999  384127100  23.742037

# %%
msft_df['high'].min()
# Out:
# 24.299999237060547

# %%
msft_df.loc[msft_df['high']==24.299999237060547]
# Out:
#                      high    low  open  close     volume   adjclose
# formatted_date
# 2010-09-04      24.299999  23.74  24.1  23.85  221754300  18.470181
