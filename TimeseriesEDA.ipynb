# %%
## Install pandas data reader
# !pip install pandas-datareader

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
# !pip install yfinance
# Out:
# ...
#   Using cached pandas-1.5.3-cp39-cp39-win_amd64.whl (10.9 MB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# ...
#   Using cached yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
# ...
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# ...
#   Using cached frozendict-2.3.5-cp39-cp39-win_amd64.whl (35 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# ...
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# ...

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime
import sys
import yfinance as yf

# %%
pdr.get_data_yahoo('TSLA')

# %%
TSLA = "TSLA"

# %%
data = yf.get_data_yahoo('TSLA')

print(data)

# %%
y_symbols = ['TSLA']
from datetime import datetime
startdate = datetime(2022,12,1)
enddate = datetime(2022,12,15)
data = pdr.get_data_yahoo(symbols = y_symbols, start=startdate, end=enddate)

# %%
df_tesla = pd.read_csv('data/TSLA.csv', index_col='Date',parse_dates=True)

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume
# Date
# 2021-10-08  16711100
# 2021-10-11  14200300
# 2021-10-12  22020000
# 2021-10-13  14120100
# 2021-10-14  12203200

# %%
df_tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume
# Date
# 2021-10-08  16711100
# 2021-10-11  14200300
# 2021-10-12  22020000
# 2021-10-13  14120100
# 2021-10-14  12203200

# %%
df_tesla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2843.000000  2843.000000  2843.000000  2843.000000  2843.000000
# mean    105.868475   108.031370   103.555733   105.924597   105.924597
# std     188.738974   192.483055   184.638617   188.836358   188.836358
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%      10.698000    11.026000    10.420000    10.727000    10.727000
# 50%      45.874001    46.493999    45.102001    45.916000    45.916000
# 75%      65.021000    66.251999    64.015001    65.275002    65.275002
# max     891.380005   900.400024   871.599976   883.090027   883.090027
#
#              Volume
# count  2.843000e+03
# mean   3.141524e+07
# std    2.841880e+07
# min    5.925000e+05
# 25%    1.251050e+07
# 50%    2.481500e+07
# 75%    4.012025e+07
# max    3.046940e+08

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4),ls='--',c='green')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-07-01', '2010-07-02', '2010-07-06', '2010-07-07',
#                '2010-07-08', '2010-07-09', '2010-07-12', '2010-07-13',
#                '2010-07-14', '2010-07-15',
#                ...
#                '2021-10-01', '2021-10-04', '2021-10-05', '2021-10-06',
#                '2021-10-07', '2021-10-08', '2021-10-11', '2021-10-12',
#                '2021-10-13', '2021-10-14'],
#               dtype='datetime64[ns]', name='Date', length=2843, freq=None)

# %%
index = df_tesla.loc['2020-01-01':'2021-09-01'].index
share_open = df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     84.900002
# 2020-01-03     88.099998
# 2020-01-06     88.094002
# 2020-01-07     92.279999
# 2020-01-08     94.739998
#                  ...
# 2021-08-26    708.309998
# 2021-08-27    705.000000
# 2021-08-30    714.719971
# 2021-08-31    733.000000
# 2021-09-01    734.080017
# Name: Open, Length: 421, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis = plt.subplots()
plt.tight_layout()
#prevent overlaping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
##date time index

df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2843 entries, 0 to 2842
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2843 non-null   datetime64[ns]
#  1   Open       2843 non-null   float64
#  2   High       2843 non-null   float64
#  3   Low        2843 non-null   float64
#  4   Close      2843 non-null   float64
#  5   Adj Close  2843 non-null   float64
#  6   Volume     2843 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 155.6 KB

# %%
pd.to_datetime(df_tesla['Date'])
# Out:
# 0      2010-07-01
# 1      2010-07-02
# 2      2010-07-06
# 3      2010-07-07
# 4      2010-07-08
#           ...
# 2838   2021-10-08
# 2839   2021-10-11
# 2840   2021-10-12
# 2841   2021-10-13
# 2842   2021-10-14
# Name: Date, Length: 2843, dtype: datetime64[ns]

# %%
df_tesla = df_tesla.set_index('Date',drop=True)

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...                ...         ...         ...         ...         ...
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume
# Date
# 2010-07-01  41094000
# 2010-07-02  25699000
# 2010-07-06  34334500
# ...

# %%
##datetime
from datetime import datetime

# %%
datetime(2011,11,21)
# Out:
# datetime.datetime(2011, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 3, 16, 5, 17, 39, 23980)

# %%
date = datetime(2011,11,21)

# %%
date
# Out:
# datetime.datetime(2011, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2011, 11, 21)

# %%
date.day
# Out:
# 0

# %%
date.weekday()
# Out:
# 0

# %%
date.isoweekday()
# Out:
# 1

# %% [markdown]
# #Time resampling

# %%
df_tesla.head()
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# 2010-07-07  3.280  3.326  2.996  3.160      3.160  34608500
# 2010-07-08  3.228  3.504  3.114  3.492      3.492  38557000

# %%
df_tesla.resample(rule = 'A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    3.228000    3.326000    2.996000    3.160000    3.160000
# 2011-12-31    4.356000    4.454000    4.222000    4.366000    4.366000
# 2012-12-31    5.324000    5.370000    4.528000    4.558000    4.558000
# 2013-12-31    6.616000    6.676000    6.422000    6.582000    6.582000
# 2014-12-31   28.100000   29.400000   27.334000   27.868000   27.868000
# 2015-12-31   37.166000   37.858002   36.279999   37.000000   37.000000
# 2016-12-31   28.464001   30.993999   28.209999   28.733999   28.733999
# 2017-12-31   42.950001   44.066002   42.192001   43.397999   43.397999
# 2018-12-31   50.556000   52.066002   48.917999   50.112000   50.112000
# 2019-12-31   36.220001   37.335999   35.397999   35.793999   35.793999
# 2020-12-31   74.940002   80.972000   70.101997   72.244003   72.244003
# 2021-12-31  552.549988  566.210022  539.489990  563.000000  563.000000
#
#               Volume
# Date
# ...

# %%
df_tesla.resample(rule = 'A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    7.174000    7.284000    6.950000    7.094000    7.094000
# 2011-12-31    6.926000    7.000000    6.806000    6.988000    6.988000
# 2012-12-31    7.638000    7.990000    7.422000    7.602000    7.602000
# 2013-12-31   38.792000   38.900002   37.674000   38.674000   38.674000
# 2014-12-31   57.534000   58.284000   56.080002   57.208000   57.208000
# 2015-12-31   56.040001   57.330002   55.259998   56.452000   56.452000
# 2016-12-31   53.290001   53.868000   50.902000   53.084000   53.084000
# 2017-12-31   77.337997   77.921997   75.870003   77.000000   77.000000
# 2018-12-31   75.000000   77.491997   73.424004   75.914001   75.914001
# 2019-12-31   87.000000   87.061996   85.269997   86.188004   86.188004
# 2020-12-31  699.989990  718.719971  691.119995  705.669983  705.669983
# 2021-12-31  891.380005  900.400024  871.599976  883.090027  883.090027
#
#                Volume
# Date
# ...

# %%
##yaer and frequency

df_tesla.resample(rule = 'A').max()['Open'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
##Quaterly
df_tesla.resample(rule = 'QS').max()['High'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
##bussiness end frequency

df_tesla.resample(rule='BQS').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-07-01    5.000000    5.184000    4.226000    4.396000    4.396000
# 2010-10-01    7.174000    7.284000    6.950000    7.094000    7.094000
# 2011-01-03    5.718000    5.742000    5.610000    5.690000    5.690000
# 2011-04-01    6.020000    6.300000    5.910000    6.028000    6.028000
# 2011-07-01    5.978000    6.088000    5.802000    5.946000    5.946000
# 2011-10-03    6.926000    7.000000    6.806000    6.988000    6.988000
# 2012-01-02    7.638000    7.990000    7.422000    7.588000    7.588000
# 2012-04-02    7.466000    7.694000    7.334000    7.602000    7.602000
# 2012-07-02    7.000000    7.200000    6.780000    7.192000    7.192000
# 2012-10-01    7.052000    7.160000    6.990000    7.056000    7.056000
# 2013-01-01    7.890000    8.000000    7.828000    7.896000    7.896000
# 2013-04-01   22.709999   22.980000   21.341999   22.066000   22.066000
# ...

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(30,6))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df_tesla['High'].rolling(10).mean().head(20)
# Out:
# Date
# 2010-07-01       NaN
# 2010-07-02       NaN
# 2010-07-06       NaN
# 2010-07-07       NaN
# 2010-07-08       NaN
# 2010-07-09       NaN
# 2010-07-12       NaN
# 2010-07-13       NaN
# 2010-07-14       NaN
# 2010-07-15    3.9886
# 2010-07-16    3.8962
# 2010-07-19    3.8792
# 2010-07-20    3.9162
# 2010-07-21    4.0016
# 2010-07-22    4.0762
# 2010-07-23    4.1494
# 2010-07-26    4.2180
# 2010-07-27    4.2688
# 2010-07-28    4.2838
# 2010-07-29    4.2714
# Name: High, dtype: float64

# %%
df_tesla['Open : 30 days rolling'] = df_tesla['Open'].rolling(30).mean()

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# 2010-07-07    3.280000    3.326000    2.996000    3.160000    3.160000
# 2010-07-08    3.228000    3.504000    3.114000    3.492000    3.492000
# ...                ...         ...         ...         ...         ...
# 2021-10-08  796.210022  796.380005  780.909973  785.489990  785.489990
# 2021-10-11  787.650024  801.239990  785.500000  791.940002  791.940002
# 2021-10-12  800.929993  812.320007  796.570007  805.719971  805.719971
# 2021-10-13  810.469971  815.409973  805.780029  811.080017  811.080017
# 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
#
#               Volume  Open : 30 days rolling
# Date
# 2010-07-01  41094000                     NaN
# ...

# %%
df_tesla[['Open','Open : 30 days rolling']].plot(figsize=(16,5))
# Out:
# <AxesSubplot: xlabel='Date'>
